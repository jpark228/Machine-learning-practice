# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np

# !git clone https://github.com/taehojo/data.git   

Data_set = np.loadtxt("./data/ThoraricSurgery3.csv", delimiter=",")  

X = Data_set[:, 0:16]
y = Data_set[:, 16]

model = Sequential()
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 3), reused 20 (delta 2), pack-reused 0
# Unpacking objects: 100% (21/21), done.
# Epoch 1/5
# 30/30 [==============================] - 1s 2ms/step - loss: 2.2950 - accuracy: 0.4319
# Epoch 2/5
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4958 - accuracy: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4888 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.8511
