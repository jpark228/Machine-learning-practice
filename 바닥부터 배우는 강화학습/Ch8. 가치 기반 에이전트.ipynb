# %% [markdown]
# 라이브러리 import

# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# 하이퍼 파라미터 정의

# %%
#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
buffer_limit  = 50000
batch_size    = 32

# %% [markdown]
# 리플레이 버퍼 클래스

# %%
class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

# %% [markdown]
# Q 밸류 네트워크 클래스

# %%
class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
      
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,1)
        else : 
            return out.argmax().item()

# %% [markdown]
# 학습 함수

# %%
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)

        q_out = q(s)
        q_a = q_out.gather(1,a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# 메인 함수

# %%
def main():
    env = gym.make('CartPole-v1')
    q = Qnet()
    q_target = Qnet()
    q_target.load_state_dict(q.state_dict())
    memory = ReplayBuffer()

    print_interval = 20
    score = 0.0  
    optimizer = optim.Adam(q.parameters(), lr=learning_rate)

    for n_epi in range(10000):
        epsilon = max(0.01, 0.08 - 0.01*(n_epi/200)) #Linear annealing from 8% to 1%
        s = env.reset()
        done = False

        while not done:
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)      
            s_prime, r, done, info = env.step(a)
            done_mask = 0.0 if done else 1.0
            memory.put((s,a,r/100.0,s_prime, done_mask))
            s = s_prime

            score += r
            if done:
                break
            
        if memory.size()>2000:
            train(q, q_target, memory, optimizer)

        if n_epi%print_interval==0 and n_epi!=0:
            q_target.load_state_dict(q.state_dict())
            print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
                                                            n_epi, score/print_interval, memory.size(), epsilon*100))
            score = 0.0
    env.close()

# %%
if __name__ == '__main__':
    main()
# Out:
# n_episode :20, score : 10.6, n_buffer : 212, eps : 7.9%
# n_episode :40, score : 9.6, n_buffer : 403, eps : 7.8%
# n_episode :60, score : 9.7, n_buffer : 596, eps : 7.7%
# n_episode :80, score : 9.7, n_buffer : 790, eps : 7.6%
# n_episode :100, score : 9.8, n_buffer : 987, eps : 7.5%
# n_episode :120, score : 9.6, n_buffer : 1179, eps : 7.4%
# n_episode :140, score : 9.4, n_buffer : 1367, eps : 7.3%
# n_episode :160, score : 9.6, n_buffer : 1558, eps : 7.2%
# n_episode :180, score : 10.3, n_buffer : 1765, eps : 7.1%
# n_episode :200, score : 9.4, n_buffer : 1953, eps : 7.0%
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
# n_episode :220, score : 10.3, n_buffer : 2160, eps : 6.9%
# n_episode :240, score : 10.1, n_buffer : 2361, eps : 6.8%
# n_episode :260, score : 9.9, n_buffer : 2559, eps : 6.7%
# n_episode :280, score : 11.3, n_buffer : 2786, eps : 6.6%
# n_episode :300, score : 23.9, n_buffer : 3263, eps : 6.5%
# n_episode :320, score : 57.4, n_buffer : 4410, eps : 6.4%
# n_episode :340, score : 131.2, n_buffer : 7033, eps : 6.3%
# n_episode :360, score : 195.9, n_buffer : 10951, eps : 6.2%
# n_episode :380, score : 167.8, n_buffer : 14308, eps : 6.1%
# n_episode :400, score : 238.4, n_buffer : 19076, eps : 6.0%
# n_episode :420, score : 162.6, n_buffer : 22328, eps : 5.9%
# n_episode :440, score : 197.4, n_buffer : 26276, eps : 5.8%
# n_episode :460, score : 235.9, n_buffer : 30995, eps : 5.7%
# n_episode :480, score : 234.2, n_buffer : 35678, eps : 5.6%
# n_episode :500, score : 379.6, n_buffer : 43269, eps : 5.5%
# n_episode :520, score : 344.1, n_buffer : 50000, eps : 5.4%
# n_episode :540, score : 307.1, n_buffer : 50000, eps : 5.3%
# n_episode :560, score : 344.9, n_buffer : 50000, eps : 5.2%
# n_episode :580, score : 224.1, n_buffer : 50000, eps : 5.1%
# n_episode :600, score : 226.4, n_buffer : 50000, eps : 5.0%
# n_episode :620, score : 252.2, n_buffer : 50000, eps : 4.9%
# n_episode :640, score : 272.9, n_buffer : 50000, eps : 4.8%
# n_episode :660, score : 316.2, n_buffer : 50000, eps : 4.7%
# n_episode :680, score : 290.4, n_buffer : 50000, eps : 4.6%
# n_episode :700, score : 239.6, n_buffer : 50000, eps : 4.5%
# n_episode :720, score : 225.2, n_buffer : 50000, eps : 4.4%
# n_episode :740, score : 255.0, n_buffer : 50000, eps : 4.3%
# n_episode :760, score : 232.2, n_buffer : 50000, eps : 4.2%
# n_episode :780, score : 227.1, n_buffer : 50000, eps : 4.1%
# n_episode :800, score : 217.1, n_buffer : 50000, eps : 4.0%
# n_episode :820, score : 228.8, n_buffer : 50000, eps : 3.9%
# n_episode :840, score : 259.2, n_buffer : 50000, eps : 3.8%
# n_episode :860, score : 230.0, n_buffer : 50000, eps : 3.7%
# n_episode :880, score : 219.4, n_buffer : 50000, eps : 3.6%
# n_episode :900, score : 205.2, n_buffer : 50000, eps : 3.5%
# n_episode :920, score : 210.2, n_buffer : 50000, eps : 3.4%
# n_episode :940, score : 186.2, n_buffer : 50000, eps : 3.3%
# n_episode :960, score : 210.2, n_buffer : 50000, eps : 3.2%
# n_episode :980, score : 170.1, n_buffer : 50000, eps : 3.1%
# n_episode :1000, score : 198.2, n_buffer : 50000, eps : 3.0%
# n_episode :1020, score : 158.8, n_buffer : 50000, eps : 2.9%
# n_episode :1040, score : 235.5, n_buffer : 50000, eps : 2.8%
# n_episode :1060, score : 210.3, n_buffer : 50000, eps : 2.7%
# n_episode :1080, score : 229.7, n_buffer : 50000, eps : 2.6%
# n_episode :1100, score : 170.6, n_buffer : 50000, eps : 2.5%
# n_episode :1120, score : 187.9, n_buffer : 50000, eps : 2.4%
# n_episode :1140, score : 226.3, n_buffer : 50000, eps : 2.3%
# n_episode :1160, score : 214.2, n_buffer : 50000, eps : 2.2%
# n_episode :1180, score : 167.5, n_buffer : 50000, eps : 2.1%
# n_episode :1200, score : 155.2, n_buffer : 50000, eps : 2.0%
# n_episode :1220, score : 150.9, n_buffer : 50000, eps : 1.9%
# n_episode :1240, score : 203.2, n_buffer : 50000, eps : 1.8%
# n_episode :1260, score : 159.4, n_buffer : 50000, eps : 1.7%
# n_episode :1280, score : 187.2, n_buffer : 50000, eps : 1.6%
# n_episode :1300, score : 227.7, n_buffer : 50000, eps : 1.5%
# n_episode :1320, score : 184.1, n_buffer : 50000, eps : 1.4%
# n_episode :1340, score : 161.2, n_buffer : 50000, eps : 1.3%
# n_episode :1360, score : 180.9, n_buffer : 50000, eps : 1.2%
# n_episode :1380, score : 168.7, n_buffer : 50000, eps : 1.1%
# n_episode :1400, score : 119.2, n_buffer : 50000, eps : 1.0%
# n_episode :1420, score : 170.7, n_buffer : 50000, eps : 1.0%
# n_episode :1440, score : 167.7, n_buffer : 50000, eps : 1.0%
# n_episode :1460, score : 133.8, n_buffer : 50000, eps : 1.0%
# n_episode :1480, score : 118.1, n_buffer : 50000, eps : 1.0%
# n_episode :1500, score : 126.8, n_buffer : 50000, eps : 1.0%
# n_episode :1520, score : 147.2, n_buffer : 50000, eps : 1.0%
# n_episode :1540, score : 146.8, n_buffer : 50000, eps : 1.0%
# n_episode :1560, score : 158.7, n_buffer : 50000, eps : 1.0%
# n_episode :1580, score : 155.1, n_buffer : 50000, eps : 1.0%
# n_episode :1600, score : 213.1, n_buffer : 50000, eps : 1.0%
# n_episode :1620, score : 119.3, n_buffer : 50000, eps : 1.0%
# n_episode :1640, score : 22.4, n_buffer : 50000, eps : 1.0%
# n_episode :1660, score : 189.8, n_buffer : 50000, eps : 1.0%
# n_episode :1680, score : 85.7, n_buffer : 50000, eps : 1.0%
# n_episode :1700, score : 182.9, n_buffer : 50000, eps : 1.0%
# n_episode :1720, score : 136.6, n_buffer : 50000, eps : 1.0%
# n_episode :1740, score : 219.2, n_buffer : 50000, eps : 1.0%
# n_episode :1760, score : 280.4, n_buffer : 50000, eps : 1.0%
# n_episode :1780, score : 328.8, n_buffer : 50000, eps : 1.0%
# n_episode :1800, score : 285.6, n_buffer : 50000, eps : 1.0%
# n_episode :1820, score : 169.2, n_buffer : 50000, eps : 1.0%
# n_episode :1840, score : 197.4, n_buffer : 50000, eps : 1.0%
# n_episode :1860, score : 226.9, n_buffer : 50000, eps : 1.0%
# n_episode :1880, score : 221.3, n_buffer : 50000, eps : 1.0%
# n_episode :1900, score : 270.6, n_buffer : 50000, eps : 1.0%
# n_episode :1920, score : 296.4, n_buffer : 50000, eps : 1.0%
# n_episode :1940, score : 245.0, n_buffer : 50000, eps : 1.0%
# n_episode :1960, score : 291.4, n_buffer : 50000, eps : 1.0%
# n_episode :1980, score : 157.4, n_buffer : 50000, eps : 1.0%
# n_episode :2000, score : 172.2, n_buffer : 50000, eps : 1.0%
# n_episode :2020, score : 330.9, n_buffer : 50000, eps : 1.0%
# n_episode :2040, score : 374.4, n_buffer : 50000, eps : 1.0%
# n_episode :2060, score : 265.9, n_buffer : 50000, eps : 1.0%
# n_episode :2080, score : 188.8, n_buffer : 50000, eps : 1.0%
# n_episode :2100, score : 228.3, n_buffer : 50000, eps : 1.0%
# n_episode :2120, score : 243.1, n_buffer : 50000, eps : 1.0%
# n_episode :2140, score : 222.2, n_buffer : 50000, eps : 1.0%
# n_episode :2160, score : 251.2, n_buffer : 50000, eps : 1.0%
# n_episode :2180, score : 229.4, n_buffer : 50000, eps : 1.0%
# n_episode :2200, score : 270.6, n_buffer : 50000, eps : 1.0%
# n_episode :2220, score : 310.5, n_buffer : 50000, eps : 1.0%
# n_episode :2240, score : 232.0, n_buffer : 50000, eps : 1.0%
# n_episode :2260, score : 405.4, n_buffer : 50000, eps : 1.0%
# n_episode :2280, score : 345.2, n_buffer : 50000, eps : 1.0%
# n_episode :2300, score : 221.2, n_buffer : 50000, eps : 1.0%
# n_episode :2320, score : 231.3, n_buffer : 50000, eps : 1.0%
# n_episode :2340, score : 329.2, n_buffer : 50000, eps : 1.0%
# n_episode :2360, score : 412.6, n_buffer : 50000, eps : 1.0%
# n_episode :2380, score : 221.9, n_buffer : 50000, eps : 1.0%
# n_episode :2400, score : 352.9, n_buffer : 50000, eps : 1.0%
# n_episode :2420, score : 270.6, n_buffer : 50000, eps : 1.0%
# n_episode :2440, score : 338.1, n_buffer : 50000, eps : 1.0%
# n_episode :2460, score : 339.9, n_buffer : 50000, eps : 1.0%
# n_episode :2480, score : 273.6, n_buffer : 50000, eps : 1.0%
# n_episode :2500, score : 222.2, n_buffer : 50000, eps : 1.0%
# n_episode :2520, score : 282.9, n_buffer : 50000, eps : 1.0%
# n_episode :2540, score : 368.3, n_buffer : 50000, eps : 1.0%
# n_episode :2560, score : 367.4, n_buffer : 50000, eps : 1.0%
# n_episode :2580, score : 254.8, n_buffer : 50000, eps : 1.0%
# n_episode :2600, score : 327.8, n_buffer : 50000, eps : 1.0%
# n_episode :2620, score : 253.4, n_buffer : 50000, eps : 1.0%
# n_episode :2640, score : 325.4, n_buffer : 50000, eps : 1.0%
# n_episode :2660, score : 353.4, n_buffer : 50000, eps : 1.0%
# n_episode :2680, score : 442.9, n_buffer : 50000, eps : 1.0%
# n_episode :2700, score : 432.4, n_buffer : 50000, eps : 1.0%
# n_episode :2720, score : 460.3, n_buffer : 50000, eps : 1.0%
# n_episode :2740, score : 464.8, n_buffer : 50000, eps : 1.0%
# n_episode :2760, score : 441.0, n_buffer : 50000, eps : 1.0%
# n_episode :2780, score : 442.1, n_buffer : 50000, eps : 1.0%
# n_episode :2800, score : 397.8, n_buffer : 50000, eps : 1.0%
# n_episode :2820, score : 462.4, n_buffer : 50000, eps : 1.0%
# n_episode :2840, score : 492.4, n_buffer : 50000, eps : 1.0%
# n_episode :2860, score : 474.8, n_buffer : 50000, eps : 1.0%
# n_episode :2880, score : 464.9, n_buffer : 50000, eps : 1.0%
# n_episode :2900, score : 471.1, n_buffer : 50000, eps : 1.0%
# n_episode :2920, score : 408.1, n_buffer : 50000, eps : 1.0%
# n_episode :2940, score : 413.6, n_buffer : 50000, eps : 1.0%
# n_episode :2960, score : 398.9, n_buffer : 50000, eps : 1.0%
# n_episode :2980, score : 415.7, n_buffer : 50000, eps : 1.0%
# n_episode :3000, score : 434.2, n_buffer : 50000, eps : 1.0%
# n_episode :3020, score : 471.8, n_buffer : 50000, eps : 1.0%
# n_episode :3040, score : 405.6, n_buffer : 50000, eps : 1.0%
# n_episode :3060, score : 406.7, n_buffer : 50000, eps : 1.0%
# n_episode :3080, score : 419.5, n_buffer : 50000, eps : 1.0%
# n_episode :3100, score : 331.3, n_buffer : 50000, eps : 1.0%
# n_episode :3120, score : 363.6, n_buffer : 50000, eps : 1.0%
# n_episode :3140, score : 360.2, n_buffer : 50000, eps : 1.0%
# n_episode :3160, score : 306.7, n_buffer : 50000, eps : 1.0%
# n_episode :3180, score : 401.8, n_buffer : 50000, eps : 1.0%
# n_episode :3200, score : 390.2, n_buffer : 50000, eps : 1.0%
# n_episode :3220, score : 393.2, n_buffer : 50000, eps : 1.0%
# n_episode :3240, score : 433.4, n_buffer : 50000, eps : 1.0%
# n_episode :3260, score : 294.5, n_buffer : 50000, eps : 1.0%
# n_episode :3280, score : 360.4, n_buffer : 50000, eps : 1.0%
# n_episode :3300, score : 463.6, n_buffer : 50000, eps : 1.0%
# n_episode :3320, score : 463.8, n_buffer : 50000, eps : 1.0%
# n_episode :3340, score : 373.8, n_buffer : 50000, eps : 1.0%
# n_episode :3360, score : 366.5, n_buffer : 50000, eps : 1.0%
# n_episode :3380, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :3400, score : 456.5, n_buffer : 50000, eps : 1.0%
# n_episode :3420, score : 460.5, n_buffer : 50000, eps : 1.0%
# n_episode :3440, score : 412.7, n_buffer : 50000, eps : 1.0%
# n_episode :3460, score : 364.8, n_buffer : 50000, eps : 1.0%
# n_episode :3480, score : 281.2, n_buffer : 50000, eps : 1.0%
# n_episode :3500, score : 311.8, n_buffer : 50000, eps : 1.0%
# n_episode :3520, score : 385.4, n_buffer : 50000, eps : 1.0%
# n_episode :3540, score : 420.3, n_buffer : 50000, eps : 1.0%
# n_episode :3560, score : 343.9, n_buffer : 50000, eps : 1.0%
# n_episode :3580, score : 299.4, n_buffer : 50000, eps : 1.0%
# n_episode :3600, score : 386.2, n_buffer : 50000, eps : 1.0%
# n_episode :3620, score : 275.9, n_buffer : 50000, eps : 1.0%
# n_episode :3640, score : 359.4, n_buffer : 50000, eps : 1.0%
# n_episode :3660, score : 275.1, n_buffer : 50000, eps : 1.0%
# n_episode :3680, score : 282.5, n_buffer : 50000, eps : 1.0%
# n_episode :3700, score : 284.6, n_buffer : 50000, eps : 1.0%
# n_episode :3720, score : 243.6, n_buffer : 50000, eps : 1.0%
# n_episode :3740, score : 185.8, n_buffer : 50000, eps : 1.0%
# n_episode :3760, score : 227.2, n_buffer : 50000, eps : 1.0%
# n_episode :3780, score : 179.2, n_buffer : 50000, eps : 1.0%
# n_episode :3800, score : 246.6, n_buffer : 50000, eps : 1.0%
# n_episode :3820, score : 259.4, n_buffer : 50000, eps : 1.0%
# n_episode :3840, score : 194.1, n_buffer : 50000, eps : 1.0%
# n_episode :3860, score : 246.1, n_buffer : 50000, eps : 1.0%
# n_episode :3880, score : 208.2, n_buffer : 50000, eps : 1.0%
# n_episode :3900, score : 242.8, n_buffer : 50000, eps : 1.0%
# n_episode :3920, score : 246.7, n_buffer : 50000, eps : 1.0%
# n_episode :3940, score : 294.8, n_buffer : 50000, eps : 1.0%
# n_episode :3960, score : 275.0, n_buffer : 50000, eps : 1.0%
# n_episode :3980, score : 360.4, n_buffer : 50000, eps : 1.0%
# n_episode :4000, score : 256.9, n_buffer : 50000, eps : 1.0%
# n_episode :4020, score : 222.2, n_buffer : 50000, eps : 1.0%
# n_episode :4040, score : 401.1, n_buffer : 50000, eps : 1.0%
# n_episode :4060, score : 309.4, n_buffer : 50000, eps : 1.0%
# n_episode :4080, score : 262.9, n_buffer : 50000, eps : 1.0%
# n_episode :4100, score : 232.8, n_buffer : 50000, eps : 1.0%
# n_episode :4120, score : 232.7, n_buffer : 50000, eps : 1.0%
# n_episode :4140, score : 244.1, n_buffer : 50000, eps : 1.0%
# n_episode :4160, score : 376.1, n_buffer : 50000, eps : 1.0%
# n_episode :4180, score : 235.3, n_buffer : 50000, eps : 1.0%
# n_episode :4200, score : 359.7, n_buffer : 50000, eps : 1.0%
# n_episode :4220, score : 302.9, n_buffer : 50000, eps : 1.0%
# n_episode :4240, score : 326.9, n_buffer : 50000, eps : 1.0%
# n_episode :4260, score : 299.2, n_buffer : 50000, eps : 1.0%
# n_episode :4280, score : 424.6, n_buffer : 50000, eps : 1.0%
# n_episode :4300, score : 384.6, n_buffer : 50000, eps : 1.0%
# n_episode :4320, score : 438.4, n_buffer : 50000, eps : 1.0%
# n_episode :4340, score : 464.4, n_buffer : 50000, eps : 1.0%
# n_episode :4360, score : 334.9, n_buffer : 50000, eps : 1.0%
# n_episode :4380, score : 359.0, n_buffer : 50000, eps : 1.0%
# n_episode :4400, score : 310.9, n_buffer : 50000, eps : 1.0%
# n_episode :4420, score : 330.7, n_buffer : 50000, eps : 1.0%
# n_episode :4440, score : 336.9, n_buffer : 50000, eps : 1.0%
# n_episode :4460, score : 422.3, n_buffer : 50000, eps : 1.0%
# n_episode :4480, score : 444.9, n_buffer : 50000, eps : 1.0%
# n_episode :4500, score : 478.8, n_buffer : 50000, eps : 1.0%
# n_episode :4520, score : 409.8, n_buffer : 50000, eps : 1.0%
# n_episode :4540, score : 487.1, n_buffer : 50000, eps : 1.0%
# n_episode :4560, score : 494.7, n_buffer : 50000, eps : 1.0%
# n_episode :4580, score : 456.3, n_buffer : 50000, eps : 1.0%
# n_episode :4600, score : 482.4, n_buffer : 50000, eps : 1.0%
# n_episode :4620, score : 426.3, n_buffer : 50000, eps : 1.0%
# n_episode :4640, score : 376.9, n_buffer : 50000, eps : 1.0%
# n_episode :4660, score : 441.2, n_buffer : 50000, eps : 1.0%
# n_episode :4680, score : 474.8, n_buffer : 50000, eps : 1.0%
# n_episode :4700, score : 443.2, n_buffer : 50000, eps : 1.0%
# n_episode :4720, score : 446.1, n_buffer : 50000, eps : 1.0%
# n_episode :4740, score : 372.1, n_buffer : 50000, eps : 1.0%
# n_episode :4760, score : 368.3, n_buffer : 50000, eps : 1.0%
# n_episode :4780, score : 416.4, n_buffer : 50000, eps : 1.0%
# n_episode :4800, score : 295.4, n_buffer : 50000, eps : 1.0%
# n_episode :4820, score : 280.7, n_buffer : 50000, eps : 1.0%
# n_episode :4840, score : 347.1, n_buffer : 50000, eps : 1.0%
# n_episode :4860, score : 285.8, n_buffer : 50000, eps : 1.0%
# n_episode :4880, score : 322.3, n_buffer : 50000, eps : 1.0%
# n_episode :4900, score : 372.4, n_buffer : 50000, eps : 1.0%
# n_episode :4920, score : 411.1, n_buffer : 50000, eps : 1.0%
# n_episode :4940, score : 373.3, n_buffer : 50000, eps : 1.0%
# n_episode :4960, score : 423.7, n_buffer : 50000, eps : 1.0%
# n_episode :4980, score : 447.1, n_buffer : 50000, eps : 1.0%
# n_episode :5000, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :5020, score : 432.1, n_buffer : 50000, eps : 1.0%
# n_episode :5040, score : 469.6, n_buffer : 50000, eps : 1.0%
# n_episode :5060, score : 423.7, n_buffer : 50000, eps : 1.0%
# n_episode :5080, score : 353.4, n_buffer : 50000, eps : 1.0%
# n_episode :5100, score : 442.2, n_buffer : 50000, eps : 1.0%
# n_episode :5120, score : 446.9, n_buffer : 50000, eps : 1.0%
# n_episode :5140, score : 375.2, n_buffer : 50000, eps : 1.0%
# n_episode :5160, score : 445.4, n_buffer : 50000, eps : 1.0%
# n_episode :5180, score : 380.0, n_buffer : 50000, eps : 1.0%
# n_episode :5200, score : 417.9, n_buffer : 50000, eps : 1.0%
# n_episode :5220, score : 450.8, n_buffer : 50000, eps : 1.0%
# n_episode :5240, score : 372.4, n_buffer : 50000, eps : 1.0%
# n_episode :5260, score : 349.8, n_buffer : 50000, eps : 1.0%
# n_episode :5280, score : 372.3, n_buffer : 50000, eps : 1.0%
# n_episode :5300, score : 354.7, n_buffer : 50000, eps : 1.0%
# n_episode :5320, score : 358.6, n_buffer : 50000, eps : 1.0%
# n_episode :5340, score : 396.9, n_buffer : 50000, eps : 1.0%
# n_episode :5360, score : 262.6, n_buffer : 50000, eps : 1.0%
# n_episode :5380, score : 360.1, n_buffer : 50000, eps : 1.0%
# n_episode :5400, score : 399.9, n_buffer : 50000, eps : 1.0%
# n_episode :5420, score : 373.7, n_buffer : 50000, eps : 1.0%
# n_episode :5440, score : 279.6, n_buffer : 50000, eps : 1.0%
# n_episode :5460, score : 327.8, n_buffer : 50000, eps : 1.0%
# n_episode :5480, score : 229.1, n_buffer : 50000, eps : 1.0%
# n_episode :5500, score : 138.3, n_buffer : 50000, eps : 1.0%
# n_episode :5520, score : 161.4, n_buffer : 50000, eps : 1.0%
# n_episode :5540, score : 210.1, n_buffer : 50000, eps : 1.0%
# n_episode :5560, score : 136.9, n_buffer : 50000, eps : 1.0%
# n_episode :5580, score : 149.1, n_buffer : 50000, eps : 1.0%
# n_episode :5600, score : 310.9, n_buffer : 50000, eps : 1.0%
# n_episode :5620, score : 342.9, n_buffer : 50000, eps : 1.0%
# n_episode :5640, score : 437.1, n_buffer : 50000, eps : 1.0%
# n_episode :5660, score : 301.3, n_buffer : 50000, eps : 1.0%
# n_episode :5680, score : 276.4, n_buffer : 50000, eps : 1.0%
# n_episode :5700, score : 331.9, n_buffer : 50000, eps : 1.0%
# n_episode :5720, score : 356.7, n_buffer : 50000, eps : 1.0%
# n_episode :5740, score : 216.7, n_buffer : 50000, eps : 1.0%
# n_episode :5760, score : 387.2, n_buffer : 50000, eps : 1.0%
# n_episode :5780, score : 290.1, n_buffer : 50000, eps : 1.0%
# n_episode :5800, score : 333.4, n_buffer : 50000, eps : 1.0%
# n_episode :5820, score : 334.4, n_buffer : 50000, eps : 1.0%
# n_episode :5840, score : 259.7, n_buffer : 50000, eps : 1.0%
# n_episode :5860, score : 449.9, n_buffer : 50000, eps : 1.0%
# n_episode :5880, score : 451.4, n_buffer : 50000, eps : 1.0%
# n_episode :5900, score : 473.8, n_buffer : 50000, eps : 1.0%
# n_episode :5920, score : 328.8, n_buffer : 50000, eps : 1.0%
# n_episode :5940, score : 430.1, n_buffer : 50000, eps : 1.0%
# n_episode :5960, score : 343.4, n_buffer : 50000, eps : 1.0%
# n_episode :5980, score : 394.6, n_buffer : 50000, eps : 1.0%
# n_episode :6000, score : 383.9, n_buffer : 50000, eps : 1.0%
# n_episode :6020, score : 424.9, n_buffer : 50000, eps : 1.0%
# n_episode :6040, score : 268.7, n_buffer : 50000, eps : 1.0%
# n_episode :6060, score : 430.2, n_buffer : 50000, eps : 1.0%
# n_episode :6080, score : 407.8, n_buffer : 50000, eps : 1.0%
# n_episode :6100, score : 300.6, n_buffer : 50000, eps : 1.0%
# n_episode :6120, score : 377.2, n_buffer : 50000, eps : 1.0%
# n_episode :6140, score : 464.9, n_buffer : 50000, eps : 1.0%
# n_episode :6160, score : 389.9, n_buffer : 50000, eps : 1.0%
# n_episode :6180, score : 431.9, n_buffer : 50000, eps : 1.0%
# n_episode :6200, score : 412.6, n_buffer : 50000, eps : 1.0%
# n_episode :6220, score : 447.4, n_buffer : 50000, eps : 1.0%
# n_episode :6240, score : 453.8, n_buffer : 50000, eps : 1.0%
# n_episode :6260, score : 484.6, n_buffer : 50000, eps : 1.0%
# n_episode :6280, score : 465.4, n_buffer : 50000, eps : 1.0%
# n_episode :6300, score : 415.9, n_buffer : 50000, eps : 1.0%
# n_episode :6320, score : 426.1, n_buffer : 50000, eps : 1.0%
# n_episode :6340, score : 385.7, n_buffer : 50000, eps : 1.0%
# n_episode :6360, score : 462.2, n_buffer : 50000, eps : 1.0%
# n_episode :6380, score : 463.2, n_buffer : 50000, eps : 1.0%
# n_episode :6400, score : 412.0, n_buffer : 50000, eps : 1.0%
# n_episode :6420, score : 467.2, n_buffer : 50000, eps : 1.0%
# n_episode :6440, score : 376.8, n_buffer : 50000, eps : 1.0%
# n_episode :6460, score : 360.6, n_buffer : 50000, eps : 1.0%
# n_episode :6480, score : 394.2, n_buffer : 50000, eps : 1.0%
# n_episode :6500, score : 399.0, n_buffer : 50000, eps : 1.0%
# n_episode :6520, score : 425.9, n_buffer : 50000, eps : 1.0%
# n_episode :6540, score : 335.4, n_buffer : 50000, eps : 1.0%
# n_episode :6560, score : 437.9, n_buffer : 50000, eps : 1.0%
# n_episode :6580, score : 454.8, n_buffer : 50000, eps : 1.0%
# n_episode :6600, score : 459.6, n_buffer : 50000, eps : 1.0%
# n_episode :6620, score : 435.6, n_buffer : 50000, eps : 1.0%
# n_episode :6640, score : 459.8, n_buffer : 50000, eps : 1.0%
# n_episode :6660, score : 431.6, n_buffer : 50000, eps : 1.0%
# n_episode :6680, score : 432.4, n_buffer : 50000, eps : 1.0%
# n_episode :6700, score : 466.4, n_buffer : 50000, eps : 1.0%
# n_episode :6720, score : 469.0, n_buffer : 50000, eps : 1.0%
# n_episode :6740, score : 340.1, n_buffer : 50000, eps : 1.0%
# n_episode :6760, score : 366.7, n_buffer : 50000, eps : 1.0%
# n_episode :6780, score : 378.8, n_buffer : 50000, eps : 1.0%
# n_episode :6800, score : 460.6, n_buffer : 50000, eps : 1.0%
# n_episode :6820, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :6840, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :6860, score : 446.8, n_buffer : 50000, eps : 1.0%
# n_episode :6880, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :6900, score : 439.6, n_buffer : 50000, eps : 1.0%
# n_episode :6920, score : 387.3, n_buffer : 50000, eps : 1.0%
# n_episode :6940, score : 368.1, n_buffer : 50000, eps : 1.0%
# n_episode :6960, score : 436.3, n_buffer : 50000, eps : 1.0%
# n_episode :6980, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7000, score : 434.4, n_buffer : 50000, eps : 1.0%
# n_episode :7020, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7040, score : 458.9, n_buffer : 50000, eps : 1.0%
# n_episode :7060, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7080, score : 497.4, n_buffer : 50000, eps : 1.0%
# n_episode :7100, score : 483.3, n_buffer : 50000, eps : 1.0%
# n_episode :7120, score : 441.6, n_buffer : 50000, eps : 1.0%
# n_episode :7140, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7160, score : 460.3, n_buffer : 50000, eps : 1.0%
# n_episode :7180, score : 482.6, n_buffer : 50000, eps : 1.0%
# n_episode :7200, score : 498.9, n_buffer : 50000, eps : 1.0%
# n_episode :7220, score : 490.6, n_buffer : 50000, eps : 1.0%
# n_episode :7240, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7260, score : 481.5, n_buffer : 50000, eps : 1.0%
# n_episode :7280, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7300, score : 475.4, n_buffer : 50000, eps : 1.0%
# n_episode :7320, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7340, score : 482.5, n_buffer : 50000, eps : 1.0%
# n_episode :7360, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7380, score : 470.8, n_buffer : 50000, eps : 1.0%
# n_episode :7400, score : 445.6, n_buffer : 50000, eps : 1.0%
# n_episode :7420, score : 481.6, n_buffer : 50000, eps : 1.0%
# n_episode :7440, score : 479.2, n_buffer : 50000, eps : 1.0%
# n_episode :7460, score : 455.8, n_buffer : 50000, eps : 1.0%
# n_episode :7480, score : 481.8, n_buffer : 50000, eps : 1.0%
# n_episode :7500, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7520, score : 467.4, n_buffer : 50000, eps : 1.0%
# n_episode :7540, score : 358.6, n_buffer : 50000, eps : 1.0%
# n_episode :7560, score : 485.0, n_buffer : 50000, eps : 1.0%
# n_episode :7580, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7600, score : 500.0, n_buffer : 50000, eps : 1.0%
# n_episode :7620, score : 438.6, n_buffer : 50000, eps : 1.0%
# n_episode :7640, score : 433.8, n_buffer : 50000, eps : 1.0%
# n_episode :7660, score : 447.3, n_buffer : 50000, eps : 1.0%
# n_episode :7680, score : 383.4, n_buffer : 50000, eps : 1.0%
# n_episode :7700, score : 365.6, n_buffer : 50000, eps : 1.0%
# n_episode :7720, score : 361.9, n_buffer : 50000, eps : 1.0%
# n_episode :7740, score : 462.2, n_buffer : 50000, eps : 1.0%
# n_episode :7760, score : 471.7, n_buffer : 50000, eps : 1.0%
# n_episode :7780, score : 485.9, n_buffer : 50000, eps : 1.0%
# n_episode :7800, score : 411.4, n_buffer : 50000, eps : 1.0%
# n_episode :7820, score : 467.4, n_buffer : 50000, eps : 1.0%
# n_episode :7840, score : 389.9, n_buffer : 50000, eps : 1.0%
# n_episode :7860, score : 372.8, n_buffer : 50000, eps : 1.0%
# n_episode :7880, score : 238.1, n_buffer : 50000, eps : 1.0%
# n_episode :7900, score : 127.1, n_buffer : 50000, eps : 1.0%
# n_episode :7920, score : 100.6, n_buffer : 50000, eps : 1.0%
# n_episode :7940, score : 165.3, n_buffer : 50000, eps : 1.0%
# n_episode :7960, score : 155.8, n_buffer : 50000, eps : 1.0%
# n_episode :7980, score : 251.1, n_buffer : 50000, eps : 1.0%
# n_episode :8000, score : 282.1, n_buffer : 50000, eps : 1.0%
# n_episode :8020, score : 273.4, n_buffer : 50000, eps : 1.0%
# n_episode :8040, score : 261.9, n_buffer : 50000, eps : 1.0%
# n_episode :8060, score : 256.9, n_buffer : 50000, eps : 1.0%
# n_episode :8080, score : 298.6, n_buffer : 50000, eps : 1.0%
# n_episode :8100, score : 370.4, n_buffer : 50000, eps : 1.0%
# n_episode :8120, score : 354.2, n_buffer : 50000, eps : 1.0%
# n_episode :8140, score : 279.2, n_buffer : 50000, eps : 1.0%
# n_episode :8160, score : 356.6, n_buffer : 50000, eps : 1.0%
# n_episode :8180, score : 228.4, n_buffer : 50000, eps : 1.0%
# n_episode :8200, score : 160.0, n_buffer : 50000, eps : 1.0%
# n_episode :8220, score : 274.6, n_buffer : 50000, eps : 1.0%
# n_episode :8240, score : 334.9, n_buffer : 50000, eps : 1.0%
# n_episode :8260, score : 206.0, n_buffer : 50000, eps : 1.0%
# n_episode :8280, score : 117.3, n_buffer : 50000, eps : 1.0%
# n_episode :8300, score : 212.0, n_buffer : 50000, eps : 1.0%
# n_episode :8320, score : 295.7, n_buffer : 50000, eps : 1.0%
# n_episode :8340, score : 288.8, n_buffer : 50000, eps : 1.0%
# n_episode :8360, score : 160.8, n_buffer : 50000, eps : 1.0%
# n_episode :8380, score : 178.6, n_buffer : 50000, eps : 1.0%
# n_episode :8400, score : 250.8, n_buffer : 50000, eps : 1.0%
# n_episode :8420, score : 295.6, n_buffer : 50000, eps : 1.0%
# n_episode :8440, score : 257.1, n_buffer : 50000, eps : 1.0%
# n_episode :8460, score : 246.8, n_buffer : 50000, eps : 1.0%
# n_episode :8480, score : 282.8, n_buffer : 50000, eps : 1.0%
# n_episode :8500, score : 225.4, n_buffer : 50000, eps : 1.0%
# n_episode :8520, score : 258.1, n_buffer : 50000, eps : 1.0%
# n_episode :8540, score : 239.9, n_buffer : 50000, eps : 1.0%
# n_episode :8560, score : 254.3, n_buffer : 50000, eps : 1.0%
# n_episode :8580, score : 258.6, n_buffer : 50000, eps : 1.0%
# n_episode :8600, score : 213.0, n_buffer : 50000, eps : 1.0%
# n_episode :8620, score : 337.7, n_buffer : 50000, eps : 1.0%
# n_episode :8640, score : 217.1, n_buffer : 50000, eps : 1.0%
# n_episode :8660, score : 353.0, n_buffer : 50000, eps : 1.0%
# n_episode :8680, score : 270.8, n_buffer : 50000, eps : 1.0%
# n_episode :8700, score : 326.1, n_buffer : 50000, eps : 1.0%
# n_episode :8720, score : 355.7, n_buffer : 50000, eps : 1.0%
# n_episode :8740, score : 249.8, n_buffer : 50000, eps : 1.0%
# n_episode :8760, score : 185.8, n_buffer : 50000, eps : 1.0%
# n_episode :8780, score : 290.9, n_buffer : 50000, eps : 1.0%
# n_episode :8800, score : 172.8, n_buffer : 50000, eps : 1.0%
# n_episode :8820, score : 211.7, n_buffer : 50000, eps : 1.0%
# n_episode :8840, score : 267.3, n_buffer : 50000, eps : 1.0%
# n_episode :8860, score : 289.1, n_buffer : 50000, eps : 1.0%
# n_episode :8880, score : 268.4, n_buffer : 50000, eps : 1.0%
# n_episode :8900, score : 179.9, n_buffer : 50000, eps : 1.0%
# n_episode :8920, score : 259.9, n_buffer : 50000, eps : 1.0%
# n_episode :8940, score : 250.1, n_buffer : 50000, eps : 1.0%
# n_episode :8960, score : 269.4, n_buffer : 50000, eps : 1.0%
# n_episode :8980, score : 277.1, n_buffer : 50000, eps : 1.0%
# n_episode :9000, score : 256.1, n_buffer : 50000, eps : 1.0%
# n_episode :9020, score : 355.4, n_buffer : 50000, eps : 1.0%
# n_episode :9040, score : 391.6, n_buffer : 50000, eps : 1.0%
# n_episode :9060, score : 478.9, n_buffer : 50000, eps : 1.0%
# n_episode :9080, score : 422.5, n_buffer : 50000, eps : 1.0%
# n_episode :9100, score : 413.2, n_buffer : 50000, eps : 1.0%
# n_episode :9120, score : 469.3, n_buffer : 50000, eps : 1.0%
# n_episode :9140, score : 427.7, n_buffer : 50000, eps : 1.0%
# n_episode :9160, score : 395.6, n_buffer : 50000, eps : 1.0%
# n_episode :9180, score : 370.0, n_buffer : 50000, eps : 1.0%
# n_episode :9200, score : 409.6, n_buffer : 50000, eps : 1.0%
# n_episode :9220, score : 429.2, n_buffer : 50000, eps : 1.0%
# n_episode :9240, score : 398.9, n_buffer : 50000, eps : 1.0%
# n_episode :9260, score : 350.9, n_buffer : 50000, eps : 1.0%
# n_episode :9280, score : 323.8, n_buffer : 50000, eps : 1.0%
# n_episode :9300, score : 383.9, n_buffer : 50000, eps : 1.0%
# n_episode :9320, score : 366.6, n_buffer : 50000, eps : 1.0%
# n_episode :9340, score : 404.5, n_buffer : 50000, eps : 1.0%
# n_episode :9360, score : 421.2, n_buffer : 50000, eps : 1.0%
# n_episode :9380, score : 457.9, n_buffer : 50000, eps : 1.0%
# n_episode :9400, score : 444.4, n_buffer : 50000, eps : 1.0%
# n_episode :9420, score : 458.2, n_buffer : 50000, eps : 1.0%
# n_episode :9440, score : 467.7, n_buffer : 50000, eps : 1.0%
# n_episode :9460, score : 460.8, n_buffer : 50000, eps : 1.0%
# n_episode :9480, score : 485.2, n_buffer : 50000, eps : 1.0%
# n_episode :9500, score : 436.0, n_buffer : 50000, eps : 1.0%
# n_episode :9520, score : 393.2, n_buffer : 50000, eps : 1.0%
# n_episode :9540, score : 430.1, n_buffer : 50000, eps : 1.0%
# n_episode :9560, score : 258.6, n_buffer : 50000, eps : 1.0%
# n_episode :9580, score : 492.0, n_buffer : 50000, eps : 1.0%
# n_episode :9600, score : 344.1, n_buffer : 50000, eps : 1.0%
# n_episode :9620, score : 476.0, n_buffer : 50000, eps : 1.0%
# n_episode :9640, score : 468.8, n_buffer : 50000, eps : 1.0%
# n_episode :9660, score : 449.1, n_buffer : 50000, eps : 1.0%
# n_episode :9680, score : 443.1, n_buffer : 50000, eps : 1.0%
# n_episode :9700, score : 416.1, n_buffer : 50000, eps : 1.0%
# n_episode :9720, score : 466.9, n_buffer : 50000, eps : 1.0%
# n_episode :9740, score : 470.7, n_buffer : 50000, eps : 1.0%
# n_episode :9760, score : 454.4, n_buffer : 50000, eps : 1.0%
# n_episode :9780, score : 407.1, n_buffer : 50000, eps : 1.0%
# n_episode :9800, score : 441.8, n_buffer : 50000, eps : 1.0%
# n_episode :9820, score : 424.4, n_buffer : 50000, eps : 1.0%
# n_episode :9840, score : 357.2, n_buffer : 50000, eps : 1.0%
# n_episode :9860, score : 438.4, n_buffer : 50000, eps : 1.0%
# n_episode :9880, score : 422.7, n_buffer : 50000, eps : 1.0%
# n_episode :9900, score : 385.8, n_buffer : 50000, eps : 1.0%
# n_episode :9920, score : 460.5, n_buffer : 50000, eps : 1.0%
# n_episode :9940, score : 439.9, n_buffer : 50000, eps : 1.0%
# n_episode :9960, score : 316.4, n_buffer : 50000, eps : 1.0%
# n_episode :9980, score : 333.4, n_buffer : 50000, eps : 1.0%
