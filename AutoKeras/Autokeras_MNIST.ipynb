# %%
pip install autokeras

# %%
import autokeras as ak
# Out:
# Using TensorFlow backend

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
ak_model = ak.ImageClassifier(overwrite=True, max_trials=1)
ak_model.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Trial 1 Complete [00h 02m 35s]
# val_loss: 0.03857441991567612
#
# Best val_loss So Far: 0.03857441991567612
# Total elapsed time: 00h 02m 35s
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.1613 - accuracy: 0.9495
# Epoch 2/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0731 - accuracy: 0.9775
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0591 - accuracy: 0.9819
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0506 - accuracy: 0.9837
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0431 - accuracy: 0.9863
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0399 - accuracy: 0.9872
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0358 - accuracy: 0.9885
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0338 - accuracy: 0.9887
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0318 - accuracy: 0.9897
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0284 - accuracy: 0.9908

# %%
ak_model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0354 - accuracy: 0.9890
# [0.03544607013463974, 0.9890000224113464]
