# %% [markdown]
# ### IMDB 데이터셋

# %% [markdown]
# **IMDB 데이터셋 로드하기**

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# **리뷰를 다시 텍스트로 디코딩하기**

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# **정수 시퀀스를 멀티-핫 인코딩으로 인코딩하기**

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %% [markdown]
# ### 신경망 모델 만들기

# %% [markdown]
# **모델 정의하기**

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# **모델 컴파일하기**

# %%
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### 훈련 검증

# %% [markdown]
# **검증 세트 준비하기**

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# **모델 훈련하기**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 33ms/step - loss: 0.5387 - accuracy: 0.7826 - val_loss: 0.4055 - val_accuracy: 0.8592
# Epoch 2/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3241 - accuracy: 0.8999 - val_loss: 0.3170 - val_accuracy: 0.8845
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.2372 - accuracy: 0.9238 - val_loss: 0.2873 - val_accuracy: 0.8876
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1804 - accuracy: 0.9423 - val_loss: 0.2733 - val_accuracy: 0.8905
# Epoch 5/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1499 - accuracy: 0.9510 - val_loss: 0.2789 - val_accuracy: 0.8876
# Epoch 6/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1222 - accuracy: 0.9636 - val_loss: 0.2917 - val_accuracy: 0.8850
# Epoch 7/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0997 - accuracy: 0.9718 - val_loss: 0.3059 - val_accuracy: 0.8836
# Epoch 8/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0879 - accuracy: 0.9745 - val_loss: 0.3265 - val_accuracy: 0.8804
# Epoch 9/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0696 - accuracy: 0.9813 - val_loss: 0.3530 - val_accuracy: 0.8767
# Epoch 10/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0587 - accuracy: 0.9862 - val_loss: 0.3699 - val_accuracy: 0.8790
# Epoch 11/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0490 - accuracy: 0.9875 - val_loss: 0.4103 - val_accuracy: 0.8737
# Epoch 12/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0387 - accuracy: 0.9923 - val_loss: 0.4398 - val_accuracy: 0.8716
# Epoch 13/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0334 - accuracy: 0.9932 - val_loss: 0.4542 - val_accuracy: 0.8739
# Epoch 14/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0251 - accuracy: 0.9955 - val_loss: 0.4830 - val_accuracy: 0.8728
# Epoch 15/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0228 - accuracy: 0.9959 - val_loss: 0.5185 - val_accuracy: 0.8714
# Epoch 16/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0157 - accuracy: 0.9982 - val_loss: 0.5490 - val_accuracy: 0.8692
# Epoch 17/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0141 - accuracy: 0.9981 - val_loss: 0.5863 - val_accuracy: 0.8691
# Epoch 18/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.6231 - val_accuracy: 0.8650
# Epoch 19/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0062 - accuracy: 0.9998 - val_loss: 0.6572 - val_accuracy: 0.8653
# Epoch 20/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0083 - accuracy: 0.9989 - val_loss: 0.6819 - val_accuracy: 0.8661

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **훈련과 검증 손실 그리기**

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **훈련과 검증 정확도 그리기**

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **모델을 처음부터 다시 훈련하기**

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.4598 - accuracy: 0.8200
# Epoch 2/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2623 - accuracy: 0.9078
# Epoch 3/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2008 - accuracy: 0.9283
# Epoch 4/4
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1656 - accuracy: 0.9410
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3327 - accuracy: 0.8683

# %%
results
# Out:
# [0.3327040672302246, 0.8683199882507324]

# %% [markdown]
# ### 훈련된 모델로 새로운 데이터에 대해 예측하기

# %%
model.predict(x_test)
# Out:
# array([[0.12388968],
#        [0.99992543],
#        [0.55190617],
#        ...,
#        [0.07935786],
#        [0.05484593],
#        [0.2809252 ]], dtype=float32)

# %% [markdown]
# ## 뉴스 기사 분류: 다중 분류 문제

# %% [markdown]
# ### 로이터 데이터셋

# %% [markdown]
# **로이터 데이터셋 로드하기**

# %%
from tensorflow.keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# **로이터 데이터셋을 텍스트로 디코딩하기**

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in
    train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step
# 565248/550378 [==============================] - 0s 0us/step

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# **데이터 인코딩하기**

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %% [markdown]
# **레이블 인코딩하기**

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results
y_train = to_one_hot(train_labels)
y_test = to_one_hot(test_labels)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# **모델 정의하기**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %% [markdown]
# **모델 컴파일하기**

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### 훈련 검증

# %% [markdown]
# **검증 세트 준비하기**

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# **모델 훈련하기**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 38ms/step - loss: 2.5046 - accuracy: 0.4954 - val_loss: 1.6849 - val_accuracy: 0.6350
# Epoch 2/20
# 16/16 [==============================] - 0s 31ms/step - loss: 1.3953 - accuracy: 0.7077 - val_loss: 1.3119 - val_accuracy: 0.7210
# Epoch 3/20
# 16/16 [==============================] - 0s 29ms/step - loss: 1.0507 - accuracy: 0.7761 - val_loss: 1.1322 - val_accuracy: 0.7650
# Epoch 4/20
# 16/16 [==============================] - 1s 32ms/step - loss: 0.8319 - accuracy: 0.8188 - val_loss: 1.0355 - val_accuracy: 0.7800
# Epoch 5/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.6597 - accuracy: 0.8557 - val_loss: 0.9702 - val_accuracy: 0.8010
# Epoch 6/20
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5298 - accuracy: 0.8882 - val_loss: 0.9678 - val_accuracy: 0.7890
# Epoch 7/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.4239 - accuracy: 0.9141 - val_loss: 0.9066 - val_accuracy: 0.8090
# Epoch 8/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.3432 - accuracy: 0.9278 - val_loss: 0.9126 - val_accuracy: 0.8030
# Epoch 9/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2859 - accuracy: 0.9392 - val_loss: 0.9207 - val_accuracy: 0.7980
# Epoch 10/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2418 - accuracy: 0.9451 - val_loss: 0.9089 - val_accuracy: 0.8190
# Epoch 11/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2078 - accuracy: 0.9484 - val_loss: 0.9237 - val_accuracy: 0.8070
# Epoch 12/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1828 - accuracy: 0.9518 - val_loss: 0.9241 - val_accuracy: 0.8120
# Epoch 13/20
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1692 - accuracy: 0.9516 - val_loss: 0.9377 - val_accuracy: 0.8170
# Epoch 14/20
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1523 - accuracy: 0.9545 - val_loss: 0.9587 - val_accuracy: 0.8120
# Epoch 15/20
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1400 - accuracy: 0.9572 - val_loss: 0.9937 - val_accuracy: 0.8040
# Epoch 16/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1308 - accuracy: 0.9562 - val_loss: 1.0088 - val_accuracy: 0.8010
# Epoch 17/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1283 - accuracy: 0.9578 - val_loss: 1.0100 - val_accuracy: 0.8010
# Epoch 18/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1175 - accuracy: 0.9587 - val_loss: 1.0352 - val_accuracy: 0.8030
# Epoch 19/20
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1126 - accuracy: 0.9588 - val_loss: 1.1557 - val_accuracy: 0.7920
# Epoch 20/20
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1111 - accuracy: 0.9580 - val_loss: 1.1467 - val_accuracy: 0.7920

# %% [markdown]
# **훈련과 검증 손실 그리기**

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **훈련과 검증 정확도 그리기**

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **모델을 처음부터 다시 훈련하기**

# %%
model = keras.Sequential([
  layers.Dense(64, activation="relu"),
  layers.Dense(64, activation="relu"),
  layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,
          y_train,
          epochs=9,
          batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 [==============================] - 1s 26ms/step - loss: 2.5189 - accuracy: 0.5367
# Epoch 2/9
# 18/18 [==============================] - 0s 27ms/step - loss: 1.3404 - accuracy: 0.7213
# Epoch 3/9
# 18/18 [==============================] - 0s 26ms/step - loss: 1.0017 - accuracy: 0.7812
# Epoch 4/9
# 18/18 [==============================] - 0s 27ms/step - loss: 0.7882 - accuracy: 0.8299
# Epoch 5/9
# 18/18 [==============================] - 0s 26ms/step - loss: 0.6222 - accuracy: 0.8697
# Epoch 6/9
# 18/18 [==============================] - 0s 27ms/step - loss: 0.4948 - accuracy: 0.8978
# Epoch 7/9
# 18/18 [==============================] - 0s 27ms/step - loss: 0.3941 - accuracy: 0.9198
# Epoch 8/9
# 18/18 [==============================] - 1s 28ms/step - loss: 0.3255 - accuracy: 0.9305
# Epoch 9/9
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2707 - accuracy: 0.9399
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0277 - accuracy: 0.7752

# %%
results
# Out:
# [1.0277247428894043, 0.7751558423042297]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.17853962600178094

# %% [markdown]
# ### 새로운 데이터로 예측하기

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0000001

# %%
np.argmax(predictions[0])
# Out:
# 4

# %% [markdown]
# ### 레이블과 손실을 다루는 다른 방법

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### 충분히 큰 중간 층을 두어야 하는 이유

# %% [markdown]
# **정보 병목이 있는 모델**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 13ms/step - loss: 2.6902 - accuracy: 0.3405 - val_loss: 2.1303 - val_accuracy: 0.3590
# Epoch 2/20
# 63/63 [==============================] - 1s 11ms/step - loss: 1.8213 - accuracy: 0.4184 - val_loss: 1.6425 - val_accuracy: 0.5850
# Epoch 3/20
# 63/63 [==============================] - 1s 11ms/step - loss: 1.4067 - accuracy: 0.6657 - val_loss: 1.4398 - val_accuracy: 0.6660
# Epoch 4/20
# 63/63 [==============================] - 1s 11ms/step - loss: 1.2172 - accuracy: 0.7124 - val_loss: 1.3847 - val_accuracy: 0.6840
# Epoch 5/20
# 63/63 [==============================] - 1s 11ms/step - loss: 1.1102 - accuracy: 0.7298 - val_loss: 1.3810 - val_accuracy: 0.6910
# Epoch 6/20
# 63/63 [==============================] - 1s 11ms/step - loss: 1.0365 - accuracy: 0.7404 - val_loss: 1.4273 - val_accuracy: 0.6880
# Epoch 7/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.9804 - accuracy: 0.7518 - val_loss: 1.4246 - val_accuracy: 0.6850
# Epoch 8/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.9350 - accuracy: 0.7600 - val_loss: 1.4129 - val_accuracy: 0.6950
# Epoch 9/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8944 - accuracy: 0.7611 - val_loss: 1.4749 - val_accuracy: 0.6890
# Epoch 10/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8594 - accuracy: 0.7645 - val_loss: 1.4742 - val_accuracy: 0.6910
# Epoch 11/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8309 - accuracy: 0.7646 - val_loss: 1.5167 - val_accuracy: 0.6930
# Epoch 12/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8035 - accuracy: 0.7648 - val_loss: 1.5693 - val_accuracy: 0.6850
# Epoch 13/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7789 - accuracy: 0.7656 - val_loss: 1.5876 - val_accuracy: 0.6860
# Epoch 14/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7599 - accuracy: 0.7670 - val_loss: 1.6475 - val_accuracy: 0.6900
# Epoch 15/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.7398 - accuracy: 0.7662 - val_loss: 1.6895 - val_accuracy: 0.6850
# Epoch 16/20
# 63/63 [==============================] - 1s 15ms/step - loss: 0.7257 - accuracy: 0.7682 - val_loss: 1.7137 - val_accuracy: 0.6780
# Epoch 17/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.7097 - accuracy: 0.7702 - val_loss: 1.7963 - val_accuracy: 0.6770
# Epoch 18/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6941 - accuracy: 0.7752 - val_loss: 1.8153 - val_accuracy: 0.6810
# Epoch 19/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6844 - accuracy: 0.7869 - val_loss: 1.9689 - val_accuracy: 0.6850
# Epoch 20/20
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6679 - accuracy: 0.7903 - val_loss: 1.9296 - val_accuracy: 0.6900

# %% [markdown]
# ### 추가 실험

# %% [markdown]
# ### 정리

# %% [markdown]
# ## 주택 가격 예측: 회귀 문제

# %% [markdown]
# ### 보스턴 주택 가격 데이터셋

# %% [markdown]
# **보스턴 주택 데이터셋 로드하기**

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# 65536/57026 [==================================] - 0s 0us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# **데이터 정규화하기**

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# **모델 정의하기**

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %% [markdown]
# ### K-겹 검증을 사용한 훈련 검증

# %% [markdown]
# **K-겹 검증하기**

# %%
k = 4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print(f"#{i}번째 폴드 처리중")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=16, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# #0번째 폴드 처리중
# #1번째 폴드 처리중
# #2번째 폴드 처리중
# #3번째 폴드 처리중

# %%
all_scores
# Out:
# [1.8999674320220947, 2.5740745067596436, 2.472306728363037, 2.426372766494751]

# %%
np.mean(all_scores)
# Out:
# 2.3431803584098816

# %% [markdown]
# **각 폴드의 검증 점수를 저장하기**

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
    print(f"#{i}번째 폴드 처리중")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=16, verbose=0)
    mae_history = history.history["val_mae"]
    all_mae_histories.append(mae_history)
# Out:
# #0번째 폴드 처리중
# #1번째 폴드 처리중
# #2번째 폴드 처리중
# #3번째 폴드 처리중

# %% [markdown]
# **K-겹 검증 점수 평균을 기록하기**

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %% [markdown]
# **검증 점수 그래프 그리기**

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **처음 10개의 데이터 포인트를 제외한 검증 점수 그래프 그리기**

# %%
truncated_mae_history = average_mae_history[10:]
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **최종 모델 훈련하기**

# %%
model = build_model()
model.fit(train_data, train_targets,
          epochs=130, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 16.4593 - mae: 2.6446

# %%
test_mae_score
# Out:
# 2.6445534229278564

# %% [markdown]
# ### 새로운 데이터에 대해 예측하기

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# array([9.211574], dtype=float32)

# %% [markdown]
# ### 정리

# %% [markdown]
# ## 요약
