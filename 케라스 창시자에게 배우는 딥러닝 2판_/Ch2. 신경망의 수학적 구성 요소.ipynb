# %% [markdown]
# ## 신경망과의 첫 만남

# %% [markdown]
# **케라스에서 MNIST 데이터셋 적재하기**

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# **신경망 구조**

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %% [markdown]
# **컴파일 단계**

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# **이미지 데이터 준비하기**

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %% [markdown]
# **모델 훈련**

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 5s 8ms/step - loss: 0.2567 - accuracy: 0.9258
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1032 - accuracy: 0.9691
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0686 - accuracy: 0.9792
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0502 - accuracy: 0.9850
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0376 - accuracy: 0.9888

# %% [markdown]
# **모델을 사용해 예측 만들기**

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# array([1.00059395e-07, 6.24363408e-11, 2.39071551e-06, 8.48257914e-05,
#        2.57071430e-11, 5.76230264e-08, 4.26453611e-14, 9.99908805e-01,
#        1.50146013e-06, 2.32989328e-06], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# 7

# %%
predictions[0][7]
# Out:
# 0.9999088

# %%
test_labels[0]
# Out:
# 7

# %% [markdown]
# **새로운 데이터에서 모델 평가하기**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"테스트 정확도: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0668 - accuracy: 0.9793
# 테스트 정확도: 0.9793000221252441

# %% [markdown]
# ## 신경망을 위한 데이터 표현

# %% [markdown]
# ### 스칼라 (랭크-0 텐서)

# %%
import numpy as np
x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# ### 벡터 (랭크-1 텐서)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# ### 행렬 (랭크-2 텐서)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim
# Out:
# 2

# %% [markdown]
# ### 랭크-3 텐서와 더 높은 랭크의 텐서

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim
# Out:
# 3

# %% [markdown]
# ### 핵심 속성

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **다섯 번째 이미지 출력하기**

# %%
import matplotlib.pyplot as plt
digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# 9

# %% [markdown]
# ### 넘파이로 텐서 조작하기

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# ### 배치 데이터

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n:128 * (n + 1)]

# %% [markdown]
# ## 신경망의 톱니바퀴: 텐서 연산

# %% [markdown]
# ### 원소별 연산

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.)
print("걸린 시간: {0:.2f} s".format(time.time() - t0))
# Out:
# 걸린 시간: 0.01 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("걸린 시간: {0:.2f} s".format(time.time() - t0))
# Out:
# 걸린 시간: 1.64 s

# %% [markdown]
# ### 브로드캐스팅

# %%
import numpy as np
X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.concatenate([y] * 32, axis=0)

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np
x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# ### 텐서 곱셈

# %%
x = np.random.random((32,))
y = np.random.random((32,))
z = np.dot(x, y)

# %%
def naive_vector_dot(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_dot(x[i, :], y)
    return z

# %%
def naive_matrix_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_dot(row_x, column_y)
    return z

# %% [markdown]
# ### 텐서 크기 변환

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
             [2., 3.],
             [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = x.reshape((2, 3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# #### 텐서플로의 그레이디언트 테이프

# %%
import tensorflow as tf
x = tf.Variable(0.)
with tf.GradientTape() as tape:
    y = 2 * x + 3
grad_of_y_wrt_x = tape.gradient(y, x)

# %%
x = tf.Variable(tf.zeros((2, 2)))
with tf.GradientTape() as tape:
    y = 2 * x + 3
grad_of_y_wrt_x = tape.gradient(y, x)

# %%
W = tf.Variable(tf.random.uniform((2, 2)))
b = tf.Variable(tf.zeros((2,)))
x = tf.random.uniform((2, 2))
with tf.GradientTape() as tape:
    y = tf.matmul(x, W) + b
grad_of_y_wrt_W_and_b = tape.gradient(y, [W, b])

# %% [markdown]
# ## 첫 번째 예제 다시 살펴보기

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2566 - accuracy: 0.9255
# Epoch 2/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1044 - accuracy: 0.9691
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0689 - accuracy: 0.9796
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0503 - accuracy: 0.9849
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0375 - accuracy: 0.9890

# %% [markdown]
# ### 텐서플로를 사용해 첫 번째 예제를 밑바닥부터 다시 구현하기

# %% [markdown]
# #### 단순한 Dense 클래스

# %%
import tensorflow as tf

class NaiveDense:
    def __init__(self, input_size, output_size, activation):
        self.activation = activation

        w_shape = (input_size, output_size)
        w_initial_value = tf.random.uniform(w_shape, minval=0, maxval=1e-1)
        self.W = tf.Variable(w_initial_value)

        b_shape = (output_size,)
        b_initial_value = tf.zeros(b_shape)
        self.b = tf.Variable(b_initial_value)

    def __call__(self, inputs):
        return self.activation(tf.matmul(inputs, self.W) + self.b)

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# #### 단순한 Sequential 클래스

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
           x = layer(x)
        return x

    @property
    def weights(self):
       weights = []
       for layer in self.layers:
           weights += layer.weights
       return weights

# %%
model = NaiveSequential([
    NaiveDense(input_size=28 * 28, output_size=512, activation=tf.nn.relu),
    NaiveDense(input_size=512, output_size=10, activation=tf.nn.softmax)
])
assert len(model.weights) == 4

# %% [markdown]
# #### 배치 제너레이터

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# ### 훈련 스텝 실행하기

# %%
def one_training_step(model, images_batch, labels_batch):
    with tf.GradientTape() as tape:
        predictions = model(images_batch)
        per_sample_losses = tf.keras.losses.sparse_categorical_crossentropy(
            labels_batch, predictions)
        average_loss = tf.reduce_mean(per_sample_losses)
    gradients = tape.gradient(average_loss, model.weights)
    update_weights(gradients, model.weights)
    return average_loss

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign_sub(g * learning_rate)

# %%
from tensorflow.keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ### 전체 훈련 루프

# %%
def fit(model, images, labels, epochs, batch_size=128):
    for epoch_counter in range(epochs):
        print(f"에포크 {epoch_counter}")
        batch_generator = BatchGenerator(images, labels)
        for batch_counter in range(batch_generator.num_batches):
            images_batch, labels_batch = batch_generator.next()
            loss = one_training_step(model, images_batch, labels_batch)
            if batch_counter % 100 == 0:
                print(f"{batch_counter}번째 배치 손실: {loss:.2f}")

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# 에포크 0
# 0번째 배치 손실: 6.22
# 100번째 배치 손실: 2.27
# 200번째 배치 손실: 2.19
# 300번째 배치 손실: 2.09
# 400번째 배치 손실: 2.19
# 에포크 1
# 0번째 배치 손실: 1.91
# 100번째 배치 손실: 1.89
# 200번째 배치 손실: 1.81
# 300번째 배치 손실: 1.70
# 400번째 배치 손실: 1.80
# 에포크 2
# 0번째 배치 손실: 1.58
# 100번째 배치 손실: 1.59
# 200번째 배치 손실: 1.49
# 300번째 배치 손실: 1.42
# 400번째 배치 손실: 1.49
# 에포크 3
# 0번째 배치 손실: 1.32
# 100번째 배치 손실: 1.35
# 200번째 배치 손실: 1.23
# 300번째 배치 손실: 1.21
# 400번째 배치 손실: 1.26
# 에포크 4
# 0번째 배치 손실: 1.12
# 100번째 배치 손실: 1.17
# 200번째 배치 손실: 1.04
# 300번째 배치 손실: 1.05
# 400번째 배치 손실: 1.10
# 에포크 5
# 0번째 배치 손실: 0.98
# 100번째 배치 손실: 1.03
# 200번째 배치 손실: 0.90
# 300번째 배치 손실: 0.93
# 400번째 배치 손실: 0.99
# 에포크 6
# 0번째 배치 손실: 0.87
# 100번째 배치 손실: 0.92
# 200번째 배치 손실: 0.80
# 300번째 배치 손실: 0.84
# 400번째 배치 손실: 0.90
# 에포크 7
# 0번째 배치 손실: 0.79
# 100번째 배치 손실: 0.83
# 200번째 배치 손실: 0.72
# 300번째 배치 손실: 0.77
# 400번째 배치 손실: 0.83
# 에포크 8
# 0번째 배치 손실: 0.72
# 100번째 배치 손실: 0.77
# 200번째 배치 손실: 0.66
# 300번째 배치 손실: 0.71
# 400번째 배치 손실: 0.78
# 에포크 9
# 0번째 배치 손실: 0.67
# 100번째 배치 손실: 0.71
# 200번째 배치 손실: 0.61
# 300번째 배치 손실: 0.67
# 400번째 배치 손실: 0.74

# %% [markdown]
# ### 모델 평가하기

# %%
predictions = model(test_images)
predictions = predictions.numpy()
predicted_labels = np.argmax(predictions, axis=1)
matches = predicted_labels == test_labels
print(f"정확도: {matches.mean():.2f}")
# Out:
# 정확도: 0.82

# %% [markdown]
# ## 요약
